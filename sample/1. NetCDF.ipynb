# %%
import sys 
sys.path.append("C:/Users/isxzl/OneDrive/Code/AutoGeo")
import AutoGeo

# %%
import netCDF4 as nc
import numpy as np
data = r'C:\Users\isxzl\OneDrive\Code\AutoGeo\data\METER\cdf\MERRA2_400.tavg1_2d_flx_Nx.20220101.nc4' # 输入文件
NC_DS = nc.Dataset(data)

# 输出文件中变量
print(NC_DS.variables.keys())
# 了解变量的基本信息
#print(NC_DS.variables) 
print(NC_DS.variables['CDH'])
# Out:
# dict_keys(['lon', 'lat', 'time', 'BSTAR', 'CDH', 'CDM', 'CDQ', 'CN', 'DISPH', 'EFLUX', 'EVAP', 'FRCAN', 'FRCCN', 'FRCLS', 'FRSEAICE', 'GHTSKIN', 'HFLUX', 'HLML', 'NIRDF', 'NIRDR', 'PBLH', 'PGENTOT', 'PRECANV', 'PRECCON', 'PRECLSC', 'PRECSNO', 'PRECTOT', 'PRECTOTCORR', 'PREVTOT', 'QLML', 'QSH', 'QSTAR', 'RHOA', 'RISFC', 'SPEED', 'SPEEDMAX', 'TAUGWX', 'TAUGWY', 'TAUX', 'TAUY', 'TCZPBL', 'TLML', 'TSH', 'TSTAR', 'ULML', 'USTAR', 'VLML', 'Z0H', 'Z0M'])
# <class 'netCDF4._netCDF4.Variable'>
# float32 CDH(time, lat, lon)
#     long_name: surface_exchange_coefficient_for_heat
#     units: kg m-2 s-1
#     _FillValue: 1000000000000000.0
#     missing_value: 1000000000000000.0
#     fmissing_value: 1000000000000000.0
#     scale_factor: 1.0
#     add_offset: 0.0
#     standard_name: surface_exchange_coefficient_for_heat
#     vmax: 1000000000000000.0
#     vmin: -1000000000000000.0
#     valid_range: [-1.e+15  1.e+15]
# unlimited dimensions: time
# current shape = (24, 361, 576)
# filling on

# %%
# 转为numpy

np.array(NC_DS.variables['CDH'][:])
# Out:
# array([[[0.00837784, 0.00837784, 0.00837784, ..., 0.00837784,
#          0.00837784, 0.00837784],
#         [0.00536804, 0.00533371, 0.00530128, ..., 0.00547104,
#          0.0054348 , 0.00540046],
#         [0.00253277, 0.00246792, 0.00240211, ..., 0.00272731,
#          0.00266246, 0.00259762],
#         ...,
#         [0.0040348 , 0.00402717, 0.00401954, ..., 0.00405578,
#          0.00404815, 0.00404243],
#         [0.00549774, 0.00549392, 0.00549011, ..., 0.005513  ,
#          0.00550918, 0.00550346],
#         [0.00736694, 0.00736694, 0.00736694, ..., 0.00736694,
#          0.00736694, 0.00736694]],
#
#        [[0.00892367, 0.00892367, 0.00892367, ..., 0.00892367,
#          0.00892367, 0.00892367],
#         [0.00636401, 0.00634112, 0.00632014, ..., 0.00643649,
#          0.00641169, 0.00638881],
#         [0.00331797, 0.00325503, 0.00319209, ..., 0.00350776,
#          0.00344481, 0.00338092],
#         ...,
#         [0.00401034, 0.00401034, 0.00400843, ..., 0.00401606,
# ...
